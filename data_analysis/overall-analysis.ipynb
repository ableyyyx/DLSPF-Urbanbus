# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

data = [3038113,
 2657879,
 4036633,
 4101437,
 4129815,
 4295788,
 3584123,
 3278121,
 4153588,
 4214125,
 4274968,
 4314148,
 4459783,
 3630841,
 3302112,
 4165119,
 4241478,
 4241261,
 4258089,
 4472766,
 3585020,
 3328273,
 4174810,
 4307388,
 4332811,
 4313591,
 3688265,
 2384682,
 2630373,
 2484699,
 3390019,
 3897627,
 4003336,
 4258061,
 3431491,
 3208127,
 4124343,
 4187191,
 4248956,
 4265152,
 4469981,
 3616182,
 3186219,
 4077273,
 4237853,
 4126941,
 4163392,
 4367273,
 3526412,
 3191562,
 4077990,
 4136125,
 4223158,
 4160162,
 4336865,
 3584787,
 3238431,
 4123437,
 4158270]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta
# 生成日期范围，假设从2017年1月1日到2017年2月28日


start_date = datetime(2017, 1, 1)
dates = [start_date + timedelta(days=i) for i in range(len(data))]


# 绘制折线图
fig = plt.figure(figsize=(10, 6))
plt.plot(dates, data, marker='o', linestyle='-')
# plt.text(dates[-1], min(data), '2017', horizontalalignment='right', verticalalignment='top',fontsize=14)
# 设置日期格式
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=5))
# plt.text(0.92, -0.15, '2017年', fontsize=14, transform=plt.gca().transAxes)
plt.text(0.92, -0.15, 'year 2017', fontsize=14, transform=plt.gca().transAxes)
# plt.xlabel('时间/天',fontsize=16)
plt.xlabel('time/date',fontsize=16)
# plt.ylabel('客流量/次',fontsize=16)
plt.ylabel('Passenger flow/times',fontsize=16)
plt.xticks(rotation=45,fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.show()
fig.savefig('./日客流量统计.svg')
